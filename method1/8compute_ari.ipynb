# %%
import numpy as np
from ast import literal_eval
import pandas as pd
from sklearn.metrics import adjusted_rand_score
from classifiers import RandomForestForCancer

# %%
with open("coad_cluster_labels.txt",'r') as file:
    cluster_labels = literal_eval(file.readline())

# %%
len(cluster_labels)
# Out:
# 362

# %%
rf_can = RandomForestForCancer(get_tr_mats=False,csvpath="COAD_snv.tsv")

# %%
rf_can.create_gold_coad()
rf_can.gold_df
# Out:
# /opt/anaconda3/envs/bioinfo/lib/python3.12/site-packages/openpyxl/worksheet/_read_only.py:79: UserWarning: Unknown extension is not supported and will be removed
#   for idx, row in parser.parse():
#                Sample Disease Subtype
# 1766  TCGA-3L-AA1B-01    COAD     CIN
# 1767  TCGA-4N-A93T-01    COAD     CIN
# 1768  TCGA-4T-AA8H-01    COAD     CIN
# 1769  TCGA-5M-AAT4-01    COAD     CIN
# 1770  TCGA-5M-AAT5-01    COAD     CIN
# ...               ...     ...     ...
# 2102  TCGA-QL-A97D-01    COAD     CIN
# 2103  TCGA-RU-A8FL-01    COAD     CIN
# 2104  TCGA-SS-A7HO-01    COAD     CIN
# 2105  TCGA-T9-A92H-01    COAD     CIN
# 2106  TCGA-WS-AB45-01    COAD     MSI
#
# [341 rows x 3 columns]

# %%
rf_can.load_data(csvpath="COAD_snv.tsv")
# Out:
# /Users/nikhilanand/Desktop/Comp Algos Project/integrated_approach/classifiers.py:67: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_heatmap['SIFT_pred'] = df_heatmap['SIFT_pred'].apply(lambda x: 1 if x=='D' else 0)

# %%
rf_can.sample_gene_matrix.shape
# Out:
# (362, 18429)

# %%
X,y = rf_can.create_training_matrix()
# Out:
# TCGA-AA-3966-01
# TCGA-AD-6901-01
# TCGA-AA-3673-01
# TCGA-A6-2679-01
# TCGA-AA-3975-01
# TCGA-AM-5821-01
# TCGA-CK-6751-01
# TCGA-AA-A02O-01
# TCGA-AA-3858-01
# TCGA-AY-A54L-01
# TCGA-AA-3941-01
# TCGA-NH-A50V-01
# TCGA-A6-A566-01
# TCGA-CK-4952-01
# TCGA-G4-6303-01
# TCGA-AD-6888-01
# TCGA-CA-6719-01
# TCGA-D5-6898-01
# TCGA-DM-A1D4-01
# TCGA-AA-3971-01
# TCGA-AA-3821-01
# TCGA-D5-6534-01
# TCGA-AA-3489-01
# TCGA-AA-3812-01
# TCGA-5M-AAT5-01
# TCGA-AA-A01Z-01
# TCGA-CM-6678-01
# TCGA-A6-6137-01
# TCGA-AZ-6605-01
# TCGA-SS-A7HO-01
# TCGA-F4-6569-01
# TCGA-AA-A02F-01
# TCGA-AA-3655-01
# TCGA-DM-A28H-01
# TCGA-QG-A5YV-01
# TCGA-AA-3846-01
# TCGA-G4-6317-01
# TCGA-AA-3989-01
# TCGA-AD-6890-01
# TCGA-G4-6311-01
# TCGA-AA-3856-01
# TCGA-CK-6747-01
# TCGA-AA-3866-01
# TCGA-CM-6170-01
# TCGA-AY-5543-01
# TCGA-CM-6680-01
# TCGA-AA-3511-01
# TCGA-CA-6716-01
# TCGA-AA-A017-01
# TCGA-DM-A0XF-01
# TCGA-AA-3842-01
# TCGA-A6-4107-01
# TCGA-AA-3680-01
# TCGA-AA-3862-01
# TCGA-G4-6320-01
# ...

# %%
len(y)
# Out:
# 362

# %%
true_labels = y.tolist()
pred_labels = cluster_labels
len(true_labels),len(pred_labels)
# Out:
# (362, 362)

# %%
na_indices = [i for i in range(len(true_labels)) if true_labels[i]==-1]

for i in range(len(true_labels)-1,-1,-1):
    if i in na_indices:
        del true_labels[i]
        del pred_labels[i]

# %%
ari = adjusted_rand_score(true_labels, pred_labels)
ari
# Out:
# 0.35369877095130303

# %%
from sklearn.metrics.cluster import normalized_mutual_info_score
nmi = normalized_mutual_info_score(true_labels, pred_labels)
nmi
# Out:
# 0.3844966521556261

# %% [markdown]
# For BRCA, got a value of 0.13
